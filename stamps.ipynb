# %% [markdown]
# # Working with JWST data for deconvolution training
# This is a tutorial/walkthrough for the research that I did with COSMOS-Web's data release. This is intended to be used to grab images from a public data set, given a pair of coordinates for a specific galaxy.

# %% [markdown]
# ## Working with one .fits file

# %%
import matplotlib.pyplot as plt
import matplotlib
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
fitspath = 'fits/'

# %% [markdown]
# ##### Pixel Input

# %%
obj = pd.read_csv('testinput.txt',sep=',',header=0)
example = fits.open(fitspath+'example.fits.gz')
# load in image
image = example[1].data
header = example[1].header
w = WCS(header)

# %%
for i in range(len(obj)): # for each object
    # get image bounds for stamp
    left = int((obj['xcenter'][i]-(obj['size'][i]/2)))
    right = int((obj['xcenter'][i]+(obj['size'][i]/2)))
    down = int((obj['ycenter'][i]-(obj['size'][i]/2)))
    up = int((obj['ycenter'][i]+(obj['size'][i]/2)))
    # crop image with matplotlib
    plt.imshow(image[down:up,left:right],cmap='gray',vmin=0,vmax=1.5)
    plt.title(f'f770w_{obj['ID'][i]}')
    plt.savefig(f'output/f770w_{obj['ID'][i]}.png')

# %% [markdown]
# ##### RA DEC Input

# %%
obj = pd.read_csv('radecinput.txt',sep=',',header=0)
example = fits.open(fitspath+'example.fits.gz')
# load in image
image = example[1].data
header = example[1].header
w = WCS(header)

# %%
ra, dec, asecr = 149.9971059,2.0278320,2.367
xpix, ypix = w.wcs_world2pix(ra,dec,1)
xpix = round(float(xpix))
ypix = round(float(ypix))
rpix = round(float((asecr/3600)/header['CDELT1'])) 
print(xpix,ypix,rpix)

# %% [markdown]
# Save as .PNG files

# %%
for i in range(len(obj)): # for each object
    xpix, ypix = w.wcs_world2pix(obj['RA'][i],obj['DEC'][i],1) # convert from RA/DEC to pixel position
    xpix = round(float(xpix))
    ypix = round(float(ypix))
    rpix = round(float((obj['asecr'][i]/3600)/header['CDELT1'])) # arcsec / 3600 = deg / (pix/deg) = pix radius
    #print(xpix,ypix,rpix) # debug print file values
    # get image bounds for stamp
    left = int((xpix-rpix))
    right = int((xpix+rpix))
    down = int((ypix-rpix))
    up = int((ypix+rpix))
    #print(left,right,up,down) # debug print image bounds
    # crop image with matplotlib
    plt.imshow(image[down:up,left:right],cmap='gray',vmin=0,vmax=1.5,origin='lower')
    plt.title(f'f770w_{obj['ID'][i]}')
    plt.savefig(f'output/f770w_{obj['ID'][i]}.png')

# %% [markdown]
# Save as .fits files

# %%
for i in range(len(obj)): # for each object
    xpix, ypix = w.wcs_world2pix(obj['RA'][i],obj['DEC'][i],1) # convert from RA/DEC to pixel position
    xpix = round(float(xpix))
    ypix = round(float(ypix))
    rpix = round(float((obj['asecr'][i]/3600)/header['CDELT1'])) # arcsec / 3600 = deg / (pix/deg) = pix radius
    #print(xpix,ypix,rpix) # debug print file values
    # get image bounds for stamp
    left = int((xpix-rpix))
    right = int((xpix+rpix))
    down = int((ypix-rpix))
    up = int((ypix+rpix))
    #print(left,right,up,down) # debug print image bounds
    # fits file saving
    outfile = f'output/f770w_{obj['ID'][i]}.fits' # prepare outbound filename
    prihdu = fits.PrimaryHDU() # set up primary first HDU
    prihdu.data = example[0].data # carry over data from original HDU
    prihdu.header = example[0].header # carry over header from original HDU
    prihdu.header.update(w[down:up,left:right].to_header()) # crop original data in HDU to fit our new image range
    scihdu = fits.ImageHDU() # set up sci HDU
    scihdu.data = example[1].data[down:up,left:right] # carry over data from original image, cropped to our bounds
    scihdu.header = example[1].header # carry over data from original sci header
    scihdu.header.update(w[down:up,left:right].to_header()) # crop data in sci header to our new bounds using WCS function and bounds
    hdulist = fits.HDUList([prihdu, scihdu]) # put both hdu's in hdulist
    hdulist.writeto(outfile, overwrite=True) # save hdu's in new fits file

# %% [markdown]
# Post-fits-check

# %%
test = fits.open('output/f770w_CoolGal7.fits')
test.info()
#test[0].header
#test[1].header
imagetest = test[1].data
# Is there an image on the Sci HDU? Was it cropped?
#plt.imshow(imagetest,cmap='gray',vmin=0,vmax=1.5,origin='lower')
#plt.title(f'f770w_CoolGal7')

# %% [markdown]
# Save as tiles

# %%
num_images  = 9
num_cols    = min(num_images, 3)
num_rows    = int(num_images / 3) + (1 if num_images % num_cols != 0 else 0)

# Create a grid of subplots.
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12,12))
list_axes = list(axes.flat)
for i in range(0,num_images): # for each object
    xpix, ypix = w.wcs_world2pix(obj['RA'][i],obj['DEC'][i],1) # convert from RA/DEC to pixel position
    xpix = round(float(xpix))
    ypix = round(float(ypix))
    rpix = round(float((obj['asecr'][i]/3600)/header['CDELT1'])) # arcsec / 3600 = deg / (pix/deg) = pix radius
    #print(xpix,ypix,rpix) # debug print file values
    # get image bounds for stamp
    left = int((xpix-rpix))
    right = int((xpix+rpix))
    down = int((ypix-rpix))
    up = int((ypix+rpix))
    #print(left,right,up,down) # debug print image bounds
    # crop image with matplotlib
    list_axes[i].imshow(image[down:up,left:right],cmap='gray',vmin=0,vmax=1.5,origin='lower')
    list_axes[i].set_title(f'f770w_{obj['ID'][i]}')
plt.tight_layout()
plt.savefig('output/galcollage.png',dpi=150)
plt.show()

# %% [markdown]
# ## Iterating through .fits

# %% [markdown]
# Logic:
# * load in os
# * get dependencies
# * have input ra/dec to check for
# * for every fits file in directory, </br>
#     if testra and testdec are within the ranges from the header</br>
#     &ensp;do the imaging stuff </br>
#     else </br>
#     &ensp;don't do that and check the next one </br>

# %%
from os import listdir
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
path = r"/home/eliasw/OneDrive/Research/Deconvolution/fits"

# %%
for file in listdir(path):
    print(file)

# %%
from astropy.io import fits
from astropy.wcs import WCS
import numpy as np

# %%
ra = []
dec = []
for i in range(len(obj)):
    print(f'Looking for {obj['Name'][i]}..') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        f = fits.open(path + "/" + file)
        image = f[1].data
        w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
        ramax,decmax = max(w.all_pix2world((image),1)) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
        print(ramax,decmax)
        if ((ramin<=obj['RA'][i]<=ramax) & (decmin<=obj['DEC'][i]<=decmax)): # if our object's values are between the files values
            # print('Here!')
            print(f'Object is in {file}')
            f.close() # close up shop
            break # if we find it, we can leave.
        else:
            # print('Absent.') # it aint here
            f.close() # close up shop

# %%
# targets we are looking for
ra = 150.3587481
dec = 2.0068304
for file in listdir(path): # look through each file
    print(file) # debug: print file name
    header = fits.getheader(path + "/" + file, ext=1)
    w = WCS(header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
    ramin,decmin = w.pixel_to_world_values(int(header['NAXIS1']),0) # takes the ra from the rightmost pixel value (least ra) [given by header axis length] and the dec from the bottom edge (bottom dec) [0]
    ramax,decmax = w.pixel_to_world_values(0,int(header['NAXIS2'])) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
    print('RA (min/max)',ramin,ramax) # debug: show RA min/max
    print('DEC (min/max)',decmin,decmax) # debug: show DEC min/max
    if (ramin<=ra<=ramax) & (decmin<=dec<=decmax): # if our values are between the files values
        print('Here!')
        break # if we find it, we can leave.
    else:
        print('Absent.') # it aint here

# %%
# targets we are looking for
ra = 150.3587481
dec = 2.0068304
for file in listdir(path): # look through each file
    print(file) # debug: print file name
    header = fits.getheader(path + "/" + file, ext=1)
    w = WCS(header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
    ramin,decmin = w.pixel_to_world_values(int(header['NAXIS1']),0) # takes the ra from the rightmost pixel value (least ra) [given by header axis length] and the dec from the bottom edge (bottom dec) [0]
    ramax,decmax = w.pixel_to_world_values(0,int(header['NAXIS2'])) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
    print('RA (min/max)',ramin,ramax) # debug: show RA min/max
    print('DEC (min/max)',decmin,decmax) # debug: show DEC min/max
    if (ramin<=ra<=ramax) & (decmin<=dec<=decmax): # if our values are between the files values
        print('Here!')
        break # if we find it, we can leave.
    else:
        print('Absent.') # it aint here

# %%
# targets we are looking for
ra = 150.3587481
dec = 2.0068304
for file in listdir(path): # look through each file
    print(file) # debug: print file name
    header = fits.getheader(path + "/" + file, ext=1)
    w = WCS(header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
    ramin,decmin = w.pixel_to_world_values(int(header['NAXIS1']),0) # takes the ra from the rightmost pixel value (least ra) [given by header axis length] and the dec from the bottom edge (bottom dec) [0]
    ramax,decmax = w.pixel_to_world_values(0,int(header['NAXIS2'])) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
    # print(ramin,ramax) # debug: show RA min/max
    # print(decmin,decmax) # debug: show DEC min/max
    if (ramin<=ra<=ramax) & (decmin<=dec<=decmax): # if our values are between the files values
        print('Here!')
        print('Processing image... Please wait dude..') # Debug: Progress Bar
        image = fits.getdata(path + "/" + file)
        xpix, ypix = w.wcs_world2pix(ra,dec,1) # convert from RA/DEC to pixel position
        xpix = round(float(xpix))
        ypix = round(float(ypix))
        rpix = round(100) # arcsec / 3600 = deg / (pix/deg) = pix radius
        # print(xpix,ypix,rpix) # debug: print file values
        # crop image with matplotlib
        plt.imshow(image[int((ypix-rpix)):int((ypix+rpix)),int((xpix-rpix)):int((xpix+rpix))],cmap='gray',vmin=0,vmax=1.5,origin='lower')
        plt.title(f'f770w_objTEST')
        plt.savefig(f'output/objTEST.png')
        break # if we find it, we can leave.
    else:
        print('Absent.') # it aint here

# %% [markdown]
# Can we make opening .fits more efficent?

# %%
# targets we are looking for
ra = 150.3587481
dec = 2.0068304
for file in listdir(path): # look through each file
    print(file) # debug: print file name
    f = fits.open(path + "/" + file)
    w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
    ramin,decmin = w.pixel_to_world_values(int(f[1].header['NAXIS1']),0) # takes the ra from the rightmost pixel value (least ra) [given by header axis length] and the dec from the bottom edge (bottom dec) [0]
    ramax,decmax = w.pixel_to_world_values(0,int(f[1].header['NAXIS2'])) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
    # print(ramin,ramax) # debug: show RA min/max
    # print(decmin,decmax) # debug: show DEC min/max
    if (ramin<=ra<=ramax) & (decmin<=dec<=decmax): # if our values are between the files values
        print('Here!')
        print('Processing image... Please wait dude..') # Debug: Progress Bar
        image = f[1].data
        xpix, ypix = w.wcs_world2pix(ra,dec,1) # convert from RA/DEC to pixel position
        xpix = round(float(xpix))
        ypix = round(float(ypix))
        rpix = round(100) # deg / (pix/deg) = pix radius
        # print(xpix,ypix,rpix) # debug: print file values
        # crop image with matplotlib
        plt.imshow(image[int((ypix-rpix)):int((ypix+rpix)),int((xpix-rpix)):int((xpix+rpix))],cmap='gray',vmin=0,vmax=1.5,origin='lower')
        plt.title(f'f770w_objTEST')
        plt.savefig(f'output/objTEST.png')
        f.close()
        break # if we find it, we can leave.
    else:
        print('Absent.') # it aint here
        f.close()

# %% [markdown]
# YES!

# %% [markdown]
# Time for more inputs! Iteration!

# %%
# these are the droi- targets we are looking for
obj = pd.read_csv('multiinput.txt',sep='\t',header=0)

# %%
obj

# %%
for i in range(len(obj)):
    print(f'Looking for {obj['Name'][i]}..') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        # print(file) # debug: print file name
        f = fits.open(path + "/" + file)
        w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
        # TROUBLE HERE V V V
        print('len=',len((0,f[1].header['NAXIS2'])))
        print(f[1].header['NAXIS1'])
        print(f[1].header['NAXIS2'])
        ymax=
        ramin,decmin = w.all_pix2world((f[1].header['NAXIS1'],0)) # takes the ra from the rightmost pixel value (least ra) [given by header axis length] and the dec from the bottom edge (bottom dec) [0]
        ramax,decmax = w.all_pix2world((0,f[1].header['NAXIS2'])) # takes the ra from the leftmost pixel value (most ra) [0] and the dec from the top edge (most dec) [given by header axis length]
        # print(ramin,ramax) # debug: show RA min/max
        # print(decmin,decmax) # debug: show DEC min/max
        if ((ramin<=obj['RA'][i]<=ramax) & (decmin<=obj['DEC'][i]<=decmax)): # if our object's values are between the files values
            # print('Here!')
            print(f'Object is in {file}')
            # print('Processing image... Please wait dude..') # Debug: Progress Bar
            image = f[1].data
            xpix, ypix = w.wcs_world2pix(obj['RA'][i],obj['DEC'][i],1) # convert from RA/DEC to pixel position
            xpix = round(float(xpix))
            ypix = round(float(ypix))
            rpix = round(obj['rdeg'][i]/header['CDELT1']) # deg / (pix/deg) = pix radius
            # print(xpix,ypix,rpix) # debug: print file values
            # crop image with matplotlib
            plt.imshow(image[int((ypix-rpix)):int((ypix+rpix)),int((xpix-rpix)):int((xpix+rpix))],cmap='gray',vmin=0,vmax=1.5,origin='lower')
            plt.title(f'f770w_obj{obj['Name'][i]}')
            plt.savefig(f'output/obj{obj['Name'][i]}.png')
            f.close() # close up shop
            break # if we find it, we can leave.
        else:
            # print('Absent.') # it aint here
            f.close() # close up shop

# %% [markdown]
# And its broken!!

# %% [markdown]
# We need to make a better way to find the range of coordinates

# %%
from astropy.io import fits
from astropy.wcs import WCS
import numpy as np
import multiprocessing as mp

# %%
# Open the FITS file and get WCS information
fits_file = 'fits/mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz'
hdul = fits.open(fits_file)
wcs = WCS(hdul[1].header)
image_shape = hdul[1].data.shape  # Assuming 2D image

# Function for parallel RA/Dec conversion
def convert_pixels_to_radec(pixel_chunk, wcs):
    return wcs.all_pix2world(pixel_chunk, 1)
# Generate a grid of pixel coordinates for the entire image
y_pixels, x_pixels = np.indices(image_shape)

# Define subsampling factors for different regions
edge_subsample_factor = 10   # Dense sampling for edge
middle_subsample_factor = 1000  # Sparse sampling for the middle

# Define the boundaries for edges and middle regions
# Shrink the edge region, so more of the image is middle
edge_boundary = (image_shape[0] // 10, image_shape[1] // 10)  # Shrinking the edge (12.5% from edges)
middle_boundary = (image_shape[0] // 4, image_shape[1] // 4)  # Expanding the middle region (25% from edges)

# Generate a grid of pixel coordinates for the entire image
y_pixels, x_pixels = np.indices(image_shape)

# Sample the edges (outside the shrunk middle region)
x_pixels_edges = np.concatenate([x_pixels[::edge_subsample_factor, 0],  # Left edge
                                 x_pixels[::edge_subsample_factor, -1],  # Right edge
                                 x_pixels[0, ::edge_subsample_factor],  # Top edge
                                 x_pixels[-1, ::edge_subsample_factor]])  # Bottom edge
y_pixels_edges = np.concatenate([y_pixels[::edge_subsample_factor, 0], 
                                 y_pixels[::edge_subsample_factor, -1],
                                 y_pixels[0, ::edge_subsample_factor],
                                 y_pixels[-1, ::edge_subsample_factor]])

# Sample the middle region (less dense than center but more dense than edges)
x_pixels_middle = x_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                           edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]
y_pixels_middle = y_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                           edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]


# Combine all sampled pixels
pixels_combined = np.column_stack([np.concatenate([x_pixels_edges.ravel(), x_pixels_middle.ravel()]),
                                   np.concatenate([y_pixels_edges.ravel(), y_pixels_middle.ravel()])])

# Split the pixel blocks into chunks for parallel processing
num_cores = mp.cpu_count()
pixel_chunks = np.array_split(pixels_combined, num_cores)

# Convert pixel chunks to RA/Dec in parallel
with mp.Pool(num_cores) as pool:
    ra_dec_chunks = pool.starmap(convert_pixels_to_radec, [(chunk, wcs) for chunk in pixel_chunks])

# Combine the RA/Dec results
ra_dec = np.concatenate(ra_dec_chunks, axis=0)

# Extract Right Acension (RA) values and find the min and max
ra_values = ra_dec[:, 0]  # RA is the first column (in degrees)
ra_min = np.min(ra_values)
ra_max = np.max(ra_values)

print(f"RA range: {ra_min} to {ra_max} degrees")

# Extract Declination (Dec) values and find the min and max
dec_values = ra_dec[:, 1]  # Dec is the second column (in degrees)
dec_min = np.min(dec_values)
dec_max = np.max(dec_values)

print(f"Dec range: {dec_min} to {dec_max} degrees")

# %% [markdown]
# Time to implement

# %% [markdown]
# Final?

# %%
from os import listdir
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
import numpy as np
import multiprocessing as mp
path = r"/home/eliasw/OneDrive/Research/Deconvolution/fits"

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Make some functions

# %%
# Function for parallel RA/Dec conversion
def convert_pixels_to_radec(pixel_chunk, wcs):
    return w.all_pix2world(pixel_chunk, 1, output_verify='silentfix')

# %%
def bounds(image,w):
    image_shape = image.shape  # Assuming 2D image

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Define subsampling factors for different regions
    edge_subsample_factor = 10   # Dense sampling for edge
    middle_subsample_factor = 1000  # Sparse sampling for the middle

    # Define the boundaries for edges and middle regions
    # Shrink the edge region, so more of the image is middle
    edge_boundary = (image_shape[0] // 10, image_shape[1] // 10)  # Shrinking the edge (12.5% from edges)
    middle_boundary = (image_shape[0] // 4, image_shape[1] // 4)  # Expanding the middle region (25% from edges)

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Sample the edges (outside the shrunk middle region)
    x_pixels_edges = np.concatenate([x_pixels[::edge_subsample_factor, 0],  # Left edge
                                    x_pixels[::edge_subsample_factor, -1],  # Right edge
                                    x_pixels[0, ::edge_subsample_factor],  # Top edge
                                    x_pixels[-1, ::edge_subsample_factor]])  # Bottom edge
    y_pixels_edges = np.concatenate([y_pixels[::edge_subsample_factor, 0], 
                                    y_pixels[::edge_subsample_factor, -1],
                                    y_pixels[0, ::edge_subsample_factor],
                                    y_pixels[-1, ::edge_subsample_factor]])

    # Sample the middle region (less dense than center but more dense than edges)
    x_pixels_middle = x_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]
    y_pixels_middle = y_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]


    # Combine all sampled pixels
    pixels_combined = np.column_stack([np.concatenate([x_pixels_edges.ravel(), x_pixels_middle.ravel()]),
                                    np.concatenate([y_pixels_edges.ravel(), y_pixels_middle.ravel()])])

    # Split the pixel blocks into chunks for parallel processing
    num_cores = mp.cpu_count()
    pixel_chunks = np.array_split(pixels_combined, num_cores)

    # Convert pixel chunks to RA/Dec in parallel
    with mp.Pool(num_cores) as pool:
        ra_dec_chunks = pool.starmap(convert_pixels_to_radec, [(chunk, w) for chunk in pixel_chunks])

    # Combine the RA/Dec results
    ra_dec = np.concatenate(ra_dec_chunks, axis=0)

    # Extract Right Acension (RA) values and find the min and max
    ra_values = ra_dec[:, 0]  # RA is the first column (in degrees)
    ramin = np.min(ra_values)
    ramax = np.max(ra_values)

    # Extract Declination (Dec) values and find the min and max
    dec_values = ra_dec[:, 1]  # Dec is the second column (in degrees)
    decmin = np.min(dec_values)
    decmax = np.max(dec_values)

    return ramin,ramax,decmin,decmax

# %%
# these are the droi- targets we are looking for
obj = pd.read_csv('multiinput.txt',sep='\t',header=0)

# %%
obj
# Out:
#           Name          RA       DEC      rdeg
# 0      Big Guy  150.424830  2.066517  0.002781
# 1     Number 6  150.165187  2.062385  0.000905
# 2     Long One  149.866885  2.051756  0.000998
# 3          IDK  149.876102  2.072738  0.000467
# 4  Another Big  150.279300  1.904663  0.003116
# 5  Spiral Dude  149.996595  2.119639  0.000964
# 6       Galaxy  150.360678  1.988029  0.001422
# 7    Number 17  150.178078  1.935832  0.000625

# %%
for i in range(len(obj)):
    print(f'Looking for {obj['Name'][i]}..') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        print(file) # debug: print file name
        f = fits.open(path + "/" + file)
        w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
        image = f[1].data
        # get coord bounds
        ramin,ramax,decmin,decmax = bounds(image,w)
        xpix, ypix = w.all_world2pix(obj['RA'][i],obj['DEC'][i],1) # convert from RA/DEC to pixel position
        if (0 <= xpix <= f[1].header['NAXIS1'] and 0 <= ypix <= f[1].header['NAXIS2']):
            if ((ramin<=obj['RA'][i]<=ramax) & (decmin<=obj['DEC'][i]<=decmax)) & (f[4].data[int(ypix),int(xpix)] != 0): # if our object's values are between the files values
                print(f'Object is in {file}')
                # print('Processing image... Please wait dude..') # Debug: Progress Bar
                xpix = round(float(xpix))
                ypix = round(float(ypix))
                rpix = round(obj['rdeg'][i]/f[1].header['CDELT1']) # deg / (pix/deg) = pix radius
                # print(xpix,ypix,rpix) # debug: print file values
                # crop image with matplotlib
                plt.imshow(image[int((ypix-rpix)):int((ypix+rpix)),int((xpix-rpix)):int((xpix+rpix))],cmap='gray',vmin=0,vmax=1.5,origin='lower')
                plt.title(f'f770w_obj{obj['Name'][i]}')
                plt.savefig(f'output/obj{obj['Name'][i]}.png')
                f.close(output_verify='silentfix') # close up shop
                break # if we find it, we can leave.
            else:
                print('Absent.') # it aint here
                f.close(output_verify='silentfix') # close up shop
        else:
            print('Absent.') # it aint here
            f.close(output_verify='silentfix') # close up shop
print("Finished" + "!"*100)
# Out:
#   Cell In[39], line 31
#     print("Finished" + )
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Range File

# %% [markdown]
# Bonus: Lets find the ranges for all of the fits.

# %%
from os import listdir
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
import numpy as np
import multiprocessing as mp
path = r"/home/eliasw/OneDrive/Research/Deconvolution/fits"

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing our cool functions we made.

# %%
# Function for parallel RA/Dec conversion
def convert_pixels_to_radec(pixel_chunk, wcs):
    return w.all_pix2world(pixel_chunk, 1)

# %%
def bounds(image,w):
    image_shape = image.shape  # Assuming 2D image

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Define subsampling factors for different regions
    edge_subsample_factor = 10   # Dense sampling for edge
    middle_subsample_factor = 1000  # Sparse sampling for the middle

    # Define the boundaries for edges and middle regions
    # Shrink the edge region, so more of the image is middle
    edge_boundary = (image_shape[0] // 10, image_shape[1] // 10)  # Shrinking the edge (12.5% from edges)
    middle_boundary = (image_shape[0] // 4, image_shape[1] // 4)  # Expanding the middle region (25% from edges)

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Sample the edges (outside the shrunk middle region)
    x_pixels_edges = np.concatenate([x_pixels[::edge_subsample_factor, 0],  # Left edge
                                    x_pixels[::edge_subsample_factor, -1],  # Right edge
                                    x_pixels[0, ::edge_subsample_factor],  # Top edge
                                    x_pixels[-1, ::edge_subsample_factor]])  # Bottom edge
    y_pixels_edges = np.concatenate([y_pixels[::edge_subsample_factor, 0], 
                                    y_pixels[::edge_subsample_factor, -1],
                                    y_pixels[0, ::edge_subsample_factor],
                                    y_pixels[-1, ::edge_subsample_factor]])

    # Sample the middle region (less dense than center but more dense than edges)
    x_pixels_middle = x_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]
    y_pixels_middle = y_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]


    # Combine all sampled pixels
    pixels_combined = np.column_stack([np.concatenate([x_pixels_edges.ravel(), x_pixels_middle.ravel()]),
                                    np.concatenate([y_pixels_edges.ravel(), y_pixels_middle.ravel()])])

    # Split the pixel blocks into chunks for parallel processing
    num_cores = mp.cpu_count()
    pixel_chunks = np.array_split(pixels_combined, num_cores)

    # Convert pixel chunks to RA/Dec in parallel
    with mp.Pool(num_cores) as pool:
        ra_dec_chunks = pool.starmap(convert_pixels_to_radec, [(chunk, w) for chunk in pixel_chunks])

    # Combine the RA/Dec results
    ra_dec = np.concatenate(ra_dec_chunks, axis=0)

    # Extract Right Acension (RA) values and find the min and max
    ra_values = ra_dec[:, 0]  # RA is the first column (in degrees)
    ramin = np.min(ra_values)
    ramax = np.max(ra_values)

    # Extract Declination (Dec) values and find the min and max
    dec_values = ra_dec[:, 1]  # Dec is the second column (in degrees)
    decmin = np.min(dec_values)
    decmax = np.max(dec_values)

    return ramin,ramax,decmin,decmax

# %%
# prepare file stuff
l = open('fitsrange.txt', 'w')
l.write('File\tRAmin\tRAmax\tDECmin\tDECmax\n')
for file in listdir(path):
    f = fits.open(path + "/" + file)
    w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
    image = f[1].data
    # get coord bounds
    ramin,ramax,decmin,decmax = bounds(image,w)
    l.write(f'{file}\t{ramin}\t{ramax}\t{decmin}\t{decmax}\n')

# %% [markdown]
# Now let's look at what we got.

# %%
range = pd.read_csv('fitsrange.txt',sep='\t',header=0)

# %%
range
# Out:
#                                                  File       RAmin       RAmax  \
# 0   mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d...  150.126579  150.348060
# 1   mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d...  150.262128  150.483610
# 2   mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2...  150.196296  150.417747
# 3                                     example.fits.gz  149.978850  150.025232
# 4   mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d...  149.719886  149.941346
# 5   mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d...  149.991022  150.212498
# 6   mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d...  149.855457  150.076926
# 7   mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d...  149.925220  150.146662
# 8   mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d...  149.789670  150.011104
# 9   mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d...  149.654115  149.875539
# 10  mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d...  150.060762  150.282210
#
#       DECmin    DECmax
# 0   1.937735  2.187454
# 1   1.888411  2.138133
# 2   1.707689  1.957401
# 3   1.994487  2.049157
# 4   2.085646  2.335342
# 5   1.987050  2.236763
# 6   2.036353  2.286059
# 7   1.806313  2.056018
# 8   1.855610  2.105309
# 9   1.904897  2.154587
# 10  1.757005  2.006715

# %%
print(f'Total fits range: RA:{min(range['RAmin'])} - {max(range['RAmax'])}\tDEC:{min(range['DECmin'])} - {max(range['DECmax'])}')
# Out:
# Total fits range: RA:149.65411536132606 - 150.48360984203632	DEC:1.7076893037604302 - 2.3353418126877874

# %% [markdown]
# Now we have a range of coordinates where we probably have galaxies.\
# Our view composes of a rectangle with a center of 150.06886, 2.0215156 (RA/DEC), with sides of 0.6880611 RA and 0.39394768 DEC. (deg)\
# We could use this to make an upper bound on the view of the galaxies we want.

# %% [markdown]
# ##### Actual Data

# %% [markdown]
# Now we are gonna test it on actual data. \
# COSMOS2020 has 1.7 million galaxies in the general catalog. I don't think we can run that. We are instead going to try to find the top 100 galaxies of the catalog. \
# They're around the area of our fits files.

# %%
from os import listdir
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import pandas as pd
import numpy as np
import multiprocessing as mp
path = r"/home/eliasw/OneDrive/Research/Deconvolution/fits"

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing our cool functions we made.

# %%
# Function for parallel RA/Dec conversion
def convert_pixels_to_radec(pixel_chunk, wcs):
    return w.all_pix2world(pixel_chunk, 1)

# %%
def bounds(image,w):
    image_shape = image.shape  # Assuming 2D image

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Define subsampling factors for different regions
    edge_subsample_factor = 10   # Dense sampling for edge
    middle_subsample_factor = 1000  # Sparse sampling for the middle

    # Define the boundaries for edges and middle regions
    # Shrink the edge region, so more of the image is middle
    edge_boundary = (image_shape[0] // 10, image_shape[1] // 10)  # Shrinking the edge (12.5% from edges)
    middle_boundary = (image_shape[0] // 4, image_shape[1] // 4)  # Expanding the middle region (25% from edges)

    # Generate a grid of pixel coordinates for the entire image
    y_pixels, x_pixels = np.indices(image_shape)

    # Sample the edges (outside the shrunk middle region)
    x_pixels_edges = np.concatenate([x_pixels[::edge_subsample_factor, 0],  # Left edge
                                    x_pixels[::edge_subsample_factor, -1],  # Right edge
                                    x_pixels[0, ::edge_subsample_factor],  # Top edge
                                    x_pixels[-1, ::edge_subsample_factor]])  # Bottom edge
    y_pixels_edges = np.concatenate([y_pixels[::edge_subsample_factor, 0], 
                                    y_pixels[::edge_subsample_factor, -1],
                                    y_pixels[0, ::edge_subsample_factor],
                                    y_pixels[-1, ::edge_subsample_factor]])

    # Sample the middle region (less dense than center but more dense than edges)
    x_pixels_middle = x_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]
    y_pixels_middle = y_pixels[edge_boundary[0]:-edge_boundary[0]:middle_subsample_factor,
                            edge_boundary[1]:-edge_boundary[1]:middle_subsample_factor]


    # Combine all sampled pixels
    pixels_combined = np.column_stack([np.concatenate([x_pixels_edges.ravel(), x_pixels_middle.ravel()]),
                                    np.concatenate([y_pixels_edges.ravel(), y_pixels_middle.ravel()])])

    # Split the pixel blocks into chunks for parallel processing
    num_cores = mp.cpu_count()
    pixel_chunks = np.array_split(pixels_combined, num_cores)

    # Convert pixel chunks to RA/Dec in parallel
    with mp.Pool(num_cores) as pool:
        ra_dec_chunks = pool.starmap(convert_pixels_to_radec, [(chunk, w) for chunk in pixel_chunks])

    # Combine the RA/Dec results
    ra_dec = np.concatenate(ra_dec_chunks, axis=0)

    # Extract Right Acension (RA) values and find the min and max
    ra_values = ra_dec[:, 0]  # RA is the first column (in degrees)
    ramin = np.min(ra_values)
    ramax = np.max(ra_values)

    # Extract Declination (Dec) values and find the min and max
    dec_values = ra_dec[:, 1]  # Dec is the second column (in degrees)
    decmin = np.min(dec_values)
    decmax = np.max(dec_values)

    return ramin,ramax,decmin,decmax

# %% [markdown]
# Let's get those galaxies.

# %%
obj = pd.read_csv('cosmos2020classic100.csv',sep=',',header=0)

# %%
obj
# Out:
#     Classic     RAJ2000   DEJ2000  COSMOS2015
# 0       536  150.233240  1.392387         NaN
# 1      1025  150.234091  1.392218         NaN
# 2      1026  150.233957  1.392599         NaN
# 3        72  150.231391  1.391675         NaN
# 4       455  150.230869  1.392225         NaN
# ..      ...         ...       ...         ...
# 96     2829  150.219695  1.395190         NaN
# 97      944  150.214110  1.392984         NaN
# 98     1006  150.212793  1.393061         NaN
# 99     1955  150.214005  1.394012         NaN
# 100    1649  150.211666  1.393802         NaN
#
# [101 rows x 4 columns]

# %% [markdown]
# First, we are going to have it tell us if, and how many, galaxies are in there, without printing picures. Then it will be picture time.

# %%
foundgals = 0
for i in range(len(obj)):
    print(f'Looking for Object {obj['Classic'][i]}..\t ({i}/{len(obj)})') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        print(file) # debug: print file name
        f = fits.open(path + "/" + file)
        w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
        image = f[1].data
        # get coord bounds
        ramin,ramax,decmin,decmax = bounds(image,w)
        xpix, ypix = w.all_world2pix(obj['RAJ2000'][i],obj['DEJ2000'][i],1) # convert from RA/DEC to pixel position
        if (0 <= xpix <= f[1].header['NAXIS1'] and 0 <= ypix <= f[1].header['NAXIS2']):
            if ((ramin<=obj['RAJ2000'][i]<=ramax) & (decmin<=obj['DEJ2000'][i]<=decmax)) & (f[4].data[int(ypix),int(xpix)] != 0): # if our object's values are between the files values
                print(f'Object {obj['Classic'][i]} is in {file}')
                foundgals += 1
                f.close() # close up shop
                break # if we find it, we can leave.
            else:
                print('Absent.') # it aint here
                f.close() # close up shop
        else:
            print('Absent.') # it aint here
            f.close() # close up shop
    print(f'Object {obj['Classic'][i]} is not in our fits.')
print("Finished" + "!"*100)
print(f'Found {foundgals} galaxies out of {len(obj)}')
# Out:
# Looking for Object 536..	 (0/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 536 is not in our fits.
# Looking for Object 1025..	 (1/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1025 is not in our fits.
# Looking for Object 1026..	 (2/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1026 is not in our fits.
# Looking for Object 72..	 (3/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 72 is not in our fits.
# Looking for Object 455..	 (4/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 455 is not in our fits.
# Looking for Object 1635..	 (5/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1635 is not in our fits.
# Looking for Object 2347..	 (6/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2347 is not in our fits.
# Looking for Object 8..	 (7/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 8 is not in our fits.
# Looking for Object 477..	 (8/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 477 is not in our fits.
# Looking for Object 881..	 (9/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 881 is not in our fits.
# Looking for Object 1122..	 (10/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1122 is not in our fits.
# Looking for Object 38..	 (11/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 38 is not in our fits.
# Looking for Object 1611..	 (12/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1611 is not in our fits.
# Looking for Object 2080..	 (13/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2080 is not in our fits.
# Looking for Object 1117..	 (14/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1117 is not in our fits.
# Looking for Object 7514..	 (15/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 7514 is not in our fits.
# Looking for Object 1838..	 (16/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1838 is not in our fits.
# Looking for Object 2441..	 (17/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2441 is not in our fits.
# Looking for Object 2229..	 (18/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2229 is not in our fits.
# Looking for Object 2830..	 (19/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2830 is not in our fits.
# Looking for Object 4663..	 (20/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4663 is not in our fits.
# Looking for Object 5419..	 (21/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 5419 is not in our fits.
# Looking for Object 5426..	 (22/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 5426 is not in our fits.
# Looking for Object 5795..	 (23/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 5795 is not in our fits.
# Looking for Object 1016..	 (24/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1016 is not in our fits.
# Looking for Object 11..	 (25/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 11 is not in our fits.
# Looking for Object 1314..	 (26/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1314 is not in our fits.
# Looking for Object 530..	 (27/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 530 is not in our fits.
# Looking for Object 622..	 (28/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 622 is not in our fits.
# Looking for Object 16..	 (29/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 16 is not in our fits.
# Looking for Object 1072..	 (30/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1072 is not in our fits.
# Looking for Object 1368..	 (31/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1368 is not in our fits.
# Looking for Object 3116..	 (32/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 3116 is not in our fits.
# Looking for Object 29..	 (33/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 29 is not in our fits.
# Looking for Object 1341..	 (34/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1341 is not in our fits.
# Looking for Object 1710..	 (35/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1710 is not in our fits.
# Looking for Object 1923..	 (36/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1923 is not in our fits.
# Looking for Object 3832..	 (37/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 3832 is not in our fits.
# Looking for Object 746..	 (38/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 746 is not in our fits.
# Looking for Object 1189..	 (39/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1189 is not in our fits.
# Looking for Object 2185..	 (40/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2185 is not in our fits.
# Looking for Object 4719..	 (41/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4719 is not in our fits.
# Looking for Object 2429..	 (42/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2429 is not in our fits.
# Looking for Object 2302..	 (43/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2302 is not in our fits.
# Looking for Object 1398..	 (44/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1398 is not in our fits.
# Looking for Object 3353..	 (45/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 3353 is not in our fits.
# Looking for Object 6247..	 (46/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 6247 is not in our fits.
# Looking for Object 4168..	 (47/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4168 is not in our fits.
# Looking for Object 4408..	 (48/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4408 is not in our fits.
# Looking for Object 4606..	 (49/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4606 is not in our fits.
# Looking for Object 5291..	 (50/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 5291 is not in our fits.
# Looking for Object 73..	 (51/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 73 is not in our fits.
# Looking for Object 387..	 (52/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 387 is not in our fits.
# Looking for Object 496..	 (53/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 496 is not in our fits.
# Looking for Object 1055..	 (54/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1055 is not in our fits.
# Looking for Object 110..	 (55/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 110 is not in our fits.
# Looking for Object 1166..	 (56/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1166 is not in our fits.
# Looking for Object 1246..	 (57/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1246 is not in our fits.
# Looking for Object 331..	 (58/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 331 is not in our fits.
# Looking for Object 809..	 (59/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 809 is not in our fits.
# Looking for Object 1104..	 (60/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1104 is not in our fits.
# Looking for Object 2196..	 (61/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2196 is not in our fits.
# Looking for Object 338..	 (62/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 338 is not in our fits.
# Looking for Object 1071..	 (63/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1071 is not in our fits.
# Looking for Object 1700..	 (64/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1700 is not in our fits.
# Looking for Object 2171..	 (65/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2171 is not in our fits.
# Looking for Object 1849..	 (66/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# ...
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 3309 is not in our fits.
# Looking for Object 4714..	 (79/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4714 is not in our fits.
# Looking for Object 5139..	 (80/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 5139 is not in our fits.
# Looking for Object 7499..	 (81/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 7499 is not in our fits.
# Looking for Object 4909..	 (82/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4909 is not in our fits.
# Looking for Object 6685..	 (83/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 6685 is not in our fits.
# Looking for Object 491..	 (84/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 491 is not in our fits.
# Looking for Object 495..	 (85/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 495 is not in our fits.
# Looking for Object 774..	 (86/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 774 is not in our fits.
# Looking for Object 440..	 (87/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 440 is not in our fits.
# Looking for Object 733..	 (88/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 733 is not in our fits.
# Looking for Object 1092..	 (89/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1092 is not in our fits.
# Looking for Object 999..	 (90/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 999 is not in our fits.
# Looking for Object 4465..	 (91/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 4465 is not in our fits.
# Looking for Object 6289..	 (92/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 6289 is not in our fits.
# Looking for Object 1212..	 (93/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1212 is not in our fits.
# Looking for Object 2597..	 (94/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2597 is not in our fits.
# Looking for Object 2829..	 (95/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 2829 is not in our fits.
# Looking for Object 944..	 (96/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 944 is not in our fits.
# Looking for Object 1006..	 (97/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1006 is not in our fits.
# Looking for Object 1955..	 (98/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1955 is not in our fits.
# Looking for Object 1649..	 (99/100)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Object 1649 is not in our fits.
# Finished!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 25
#      23     print(f'Object {obj['Classic'][i]} is not in our fits.')
#      24 print("Finished" + "!"*100)
# ---> 25 print(f'Found {foundgals} galaxies out of {len(obj)}')
#
# NameError: name 'foundgals' is not defined

# %% [markdown]
# Damn. No galaxies. Probably should throw a test galaxy in there, that we know is in our fits files.\
# Done. 'Spiral Dude' is our test, and IS in our range, so if it says he isn't, there's a slight problem.

# %% [markdown]
# Let's also take our 100 (now 150) galaxies from a section within our range, which we found above.\
# " Total fits range: RA:149.65411536132606 - 150.48360984203632	DEC:1.7076893037604302 - 2.3353418126877874 "

# %% [markdown]
# Now we check if it works.

# %%
obj = pd.read_csv('withinrangeCOSMOS2020.csv',sep=',',header=0)

# %%
obj
# Out:
#        Classic     RAJ2000   DEJ2000
# 0       419178  149.725114  1.821626
# 1       418093  149.720245  1.821483
# 2       418141  149.720799  1.821483
# 3       418229  149.721477  1.822020
# 4       418311  149.722271  1.822107
# ...        ...         ...       ...
# 159246  840560  149.984543  2.220890
# 159247  840952  149.986198  2.220803
# 159248  842058  149.984968  2.221499
# 159249  840409  149.964419  2.220981
# 159250  840410  149.963295  2.221001
#
# [159251 rows x 3 columns]

# %% [markdown]
# That's a lot. But less than before.

# %%
foundgals = 0
for i in range(len(obj)):
    print(f'Looking for Object {obj['Classic'][i]}..\t ({i+1}/{len(obj)-1})') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        print(file) # debug: print file name
        f = fits.open(path + "/" + file)
        w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
        image = f[1].data
        # get coord bounds
        ramin,ramax,decmin,decmax = bounds(image,w)
        xpix, ypix = w.all_world2pix(obj['RAJ2000'][i],obj['DEJ2000'][i],1) # convert from RA/DEC to pixel position
        if (0 <= xpix <= f[1].header['NAXIS1'] and 0 <= ypix <= f[1].header['NAXIS2']):
            if ((ramin<=obj['RAJ2000'][i]<=ramax) & (decmin<=obj['DEJ2000'][i]<=decmax)) & (f[4].data[int(ypix),int(xpix)] != 0): # if our object's values are between the files values
                print(f'Object {obj['Classic'][i]} is in {file}')
                foundgals += 1
                f.close() # close up shop
                break # if we find it, we can leave.
            else:
                print('Absent.') # it aint here
                f.close() # close up shop
                break
        else:
            print('Absent.') # it aint here
            f.close() # close up shop
print("Finished" + "!"*100)
print(f'Found {foundgals} galaxies out of {len(obj)}')
# Out:
# Looking for Object Spiral Dude..	 (1/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Object Spiral Dude is in mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Looking for Object 123009..	 (2/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 122551..	 (3/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 122946..	 (4/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 124210..	 (5/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 124660..	 (6/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 121408..	 (7/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 121593..	 (8/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 122065..	 (9/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 123641..	 (10/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 121827..	 (11/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 122403..	 (12/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 126071..	 (13/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d.fits.gz
# Absent.
# example.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d.fits.gz
# Absent.
# Looking for Object 122236..	 (14/150)
# mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d.fits.gz
# Absent.
# mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d.fits.gz
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1270, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1269 try:
# -> 1270     return func(*args, **kwargs)
#    1271 except Exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 print(file) # debug: print file name
#       6 f = fits.open(path + "/" + file)
# ----> 7 w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
#       8 image = f[1].data
#       9 # get coord bounds
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:390, in HDUList.__getitem__(self, key)
#     386 # Originally this used recursion, but hypothetically an HDU with
#     387 # a very large number of HDUs could blow the stack, so use a loop
#     388 # instead
#     389 try:
# --> 390     return self._try_while_unread_hdus(
#     391         super().__getitem__, self._positive_index_of(key)
#     392     )
#     393 except IndexError as e:
#     394     # Raise a more helpful IndexError if the file was not fully read.
#     395     if self._read_all:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1272, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1270     return func(*args, **kwargs)
#    1271 except Exception:
# -> 1272     if self._read_next_hdu():
#    1273         continue
#    1274     else:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1311, in HDUList._read_next_hdu(self)
#    1308             offset = last._data_offset + last._data_size
#    1309             fileobj.seek(offset, os.SEEK_SET)
# -> 1311     hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1312 except EOFError:
#    1313     self._read_all = True
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/base.py:371, in _BaseHDU.readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     365 hdu = cls._readfrom_internal(
#     366     fileobj, checksum=checksum, ignore_missing_end=ignore_missing_end, **kwargs
#     367 )
#     369 # If the checksum had to be checked the data may have already been read
#     370 # from the file, in which case we don't want to seek relative
# --> 371 fileobj.seek(hdu._data_offset + hdu._data_size, os.SEEK_SET)
#     372 return hdu
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/file.py:453, in _File.seek(self, offset, whence)
#     451 if not hasattr(self._file, "seek"):
#     452     return
# --> 453 self._file.seek(offset, whence)
#     454 pos = self._file.tell()
#     455 if self.size and pos > self.size:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/gzip.py:421, in GzipFile.seek(self, offset, whence)
#     419 elif self.mode == READ:
#     420     self._check_not_closed()
# --> 421     return self._buffer.seek(offset, whence)
#     423 return self.offset
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/_compression.py:153, in DecompressReader.seek(self, offset, whence)
#     151 # Read and discard data until we reach the desired position.
#     152 while offset > 0:
# --> 153     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     154     if not data:
#     155         break
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/gzip.py:537, in _GzipReader.read(self, size)
#     535     uncompress = self._decompressor.decompress(buf, size)
#     536 else:
# --> 537     uncompress = self._decompressor.decompress(b"", size)
#     539 if self._decompressor.unused_data != b"":
#     540     # Prepend the already read bytes to the fileobj so they can
#     541     # be seen by _read_eof() and _read_gzip_header()
#     542     self._fp.prepend(self._decompressor.unused_data)
#
# KeyboardInterrupt:

# %% [markdown]
# 14 objects in 9 minutes

# %% [markdown]
# Nice! It works! ... But it's really really slow. \
# Maybe we could just use our txt file and not calculate the ranges each time?

# %%
ranges = pd.read_csv('fitsrange.txt',sep='\t',header=0)

# %%
ranges
# Out:
#                                                  File       RAmin       RAmax  \
# 0   mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d...  150.126579  150.348060
# 1   mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d...  150.262128  150.483610
# 2   mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2...  150.196296  150.417747
# 3                                     example.fits.gz  149.978850  150.025232
# 4   mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d...  149.719886  149.941346
# 5   mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d...  149.991022  150.212498
# 6   mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d...  149.855457  150.076926
# 7   mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d...  149.925220  150.146662
# 8   mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d...  149.789670  150.011104
# 9   mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d...  149.654115  149.875539
# 10  mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d...  150.060762  150.282210
#
#       DECmin    DECmax
# 0   1.937735  2.187454
# 1   1.888411  2.138133
# 2   1.707689  1.957401
# 3   1.994487  2.049157
# 4   2.085646  2.335342
# 5   1.987050  2.236763
# 6   2.036353  2.286059
# 7   1.806313  2.056018
# 8   1.855610  2.105309
# 9   1.904897  2.154587
# 10  1.757005  2.006715

# %%
print(float(ranges[ranges['File'] == file]['RAmin'])) # gets the ramin value for the column with a filename that matches the filename

# %% [markdown]
# Optimizations:
# * Instead of calculating range of .fits files, instead pull from a txt file of ranges calculated beforehand.
# * Reorder If and Loops so that resourse intensive operations are only used when they are needed. If it fails, it doesn't have to run those.
# * Introduce multiprocessing to allow use of all cores on the pc.

# %% [markdown]
# NOTE: IF ALL FITS FILES HAVE SAME AXIS LENGHTS NAXIS1 AND 2 then JUST PUT THOSE IN, ELSE, KEEP CODE SAME

# %%
foundgals = 0
for i in range(len(obj)):
    print(f'Looking for Object {obj['Classic'][i]}..\t ({i+1}/{len(obj)-1})') # Debug: What object are we on?
    for file in listdir(path): # look through each file
        # print(file) # debug: print file name
        # get coord bounds
        ramin = float(ranges[ranges['File'] == file]['RAmin'])
        ramax = float(ranges[ranges['File'] == file]['RAmax'])
        decmin = float(ranges[ranges['File'] == file]['DECmin'])
        decmax = float(ranges[ranges['File'] == file]['DECmax'])
        if (ramin <= obj['RAJ2000'][i] <= ramax) and (decmin <= obj['DEJ2000'][i] <= decmax):
            #print('in range')
            f = fits.open(path + "/" + file)
            w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
            xpix, ypix = w.all_world2pix(obj['RAJ2000'][i],obj['DEJ2000'][i],1) # convert from RA/DEC to pixel position
            if (0 <= xpix <= f[1].header['NAXIS1'] and 0 <= ypix <= f[1].header['NAXIS2']):
                #print(f'0 <= {xpix} <= {f[1].header['NAXIS1']} and 0 <= {ypix} <= {f[1].header['NAXIS2']}) <TRUE>')
                if (f[4].data[int(ypix),int(xpix)] != 0):
                    #print(f'{f[4].data[int(ypix),int(xpix)]} != 0')
                    print(f'Object {obj['Classic'][i]} is in {file}')
                    foundgals += 1
                    f.close() # close up shop
                    break # if we find it, we can leave.
                else:
                    #print(f'({f[4].data[int(ypix),int(xpix)]} != 0) <FALSE>')
                    f.close()
                    continue
            else:
                #print('Absent.') # it aint here
                #print(f'0 <= {xpix} <= {f[1].header['NAXIS1']} and 0 <= {ypix} <= {f[1].header['NAXIS2']}) <FALSE>')
                f.close() # close up shop
                continue
print("Finished" + "!"*100)
# Out:
# Looking for Object 419178..	 (1/159250)
# Looking for Object 418093..	 (2/159250)
# Looking for Object 418141..	 (3/159250)
# Looking for Object 418229..	 (4/159250)
# Looking for Object 418311..	 (5/159250)
# Looking for Object 418811..	 (6/159250)
# Looking for Object 419229..	 (7/159250)
# Looking for Object 419913..	 (8/159250)
# Looking for Object 425526..	 (9/159250)
# Looking for Object 425826..	 (10/159250)
# Looking for Object 418341..	 (11/159250)
# Looking for Object 419518..	 (12/159250)
# Looking for Object 421128..	 (13/159250)
# Looking for Object 420106..	 (14/159250)
# Looking for Object Spiral33 Dude..	 (15/159250)
# Object Spiral33 Dude is in mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d.fits.gz
# Looking for Object 421214..	 (16/159250)
# Looking for Object 422649..	 (17/159250)
# Looking for Object 421120..	 (18/159250)
# Looking for Object 421782..	 (19/159250)
# Looking for Object 421971..	 (20/159250)
# Looking for Object 422416..	 (21/159250)
# Looking for Object 423457..	 (22/159250)
# Looking for Object 422488..	 (23/159250)
# Looking for Object 423272..	 (24/159250)
# Looking for Object 424591..	 (25/159250)
# Looking for Object 423014..	 (26/159250)
# Looking for Object 425602..	 (27/159250)
# Looking for Object 423360..	 (28/159250)
# Looking for Object 424471..	 (29/159250)
# Looking for Object 424034..	 (30/159250)
# Looking for Object 424044..	 (31/159250)
# Looking for Object 424378..	 (32/159250)
# Looking for Object 424491..	 (33/159250)
# Looking for Object 425940..	 (34/159250)
# Looking for Object 417720..	 (35/159250)
# Looking for Object 417997..	 (36/159250)
# Looking for Object 418044..	 (37/159250)
# Looking for Object 418400..	 (38/159250)
# Looking for Object 418373..	 (39/159250)
# Looking for Object 417964..	 (40/159250)
# Looking for Object 418659..	 (41/159250)
# Looking for Object 419055..	 (42/159250)
# Looking for Object 419504..	 (43/159250)
# Looking for Object 421139..	 (44/159250)
# Looking for Object 419330..	 (45/159250)
# Looking for Object 419585..	 (46/159250)
# Looking for Object 419609..	 (47/159250)
# Looking for Object 420244..	 (48/159250)
# Looking for Object 421167..	 (49/159250)
# Looking for Object 419941..	 (50/159250)
# Looking for Object 420399..	 (51/159250)
# Looking for Object 420970..	 (52/159250)
# Looking for Object 421389..	 (53/159250)
# Looking for Object 421904..	 (54/159250)
# Looking for Object 422067..	 (55/159250)
# Looking for Object 422115..	 (56/159250)
# Looking for Object 423810..	 (57/159250)
# Looking for Object 424393..	 (58/159250)
# Looking for Object 424529..	 (59/159250)
# Looking for Object 418918..	 (60/159250)
# Looking for Object 419009..	 (61/159250)
# Looking for Object 427004..	 (62/159250)
# Looking for Object 418372..	 (63/159250)
# Looking for Object 418950..	 (64/159250)
# Looking for Object 419688..	 (65/159250)
# Looking for Object 419823..	 (66/159250)
# Looking for Object 418232..	 (67/159250)
# Looking for Object 420851..	 (68/159250)
# Looking for Object 419934..	 (69/159250)
# Looking for Object 420288..	 (70/159250)
# Looking for Object 420181..	 (71/159250)
# Looking for Object 420321..	 (72/159250)
# Looking for Object 421127..	 (73/159250)
# Looking for Object 421357..	 (74/159250)
# Looking for Object 418478..	 (75/159250)
# Looking for Object 418922..	 (76/159250)
# Looking for Object 421392..	 (77/159250)
# Looking for Object 419031..	 (78/159250)
# Looking for Object 421107..	 (79/159250)
# Looking for Object 421269..	 (80/159250)
# Looking for Object 421789..	 (81/159250)
# Looking for Object 420342..	 (82/159250)
# Looking for Object 421974..	 (83/159250)
# Looking for Object 422141..	 (84/159250)
# Looking for Object 422265..	 (85/159250)
# Looking for Object 422865..	 (86/159250)
# Looking for Object 424105..	 (87/159250)
# Looking for Object 418261..	 (88/159250)
# Looking for Object 419280..	 (89/159250)
# Looking for Object 419321..	 (90/159250)
# Looking for Object 417932..	 (91/159250)
# Looking for Object 417888..	 (92/159250)
# Looking for Object 418262..	 (93/159250)
# Looking for Object 418215..	 (94/159250)
# Looking for Object 418945..	 (95/159250)
# Looking for Object 418255..	 (96/159250)
# Looking for Object 419485..	 (97/159250)
# Looking for Object 418740..	 (98/159250)
# Looking for Object 418849..	 (99/159250)
# Looking for Object 420575..	 (100/159250)
# Looking for Object 420052..	 (101/159250)
# Looking for Object 421662..	 (102/159250)
# Looking for Object 419638..	 (103/159250)
# Looking for Object 420412..	 (104/159250)
# Looking for Object 420494..	 (105/159250)
# Looking for Object 420565..	 (106/159250)
# Looking for Object 420852..	 (107/159250)
# Looking for Object 418770..	 (108/159250)
# Looking for Object 420305..	 (109/159250)
# Looking for Object 418780..	 (110/159250)
# Looking for Object 418986..	 (111/159250)
# Looking for Object 419992..	 (112/159250)
# Looking for Object 422051..	 (113/159250)
# Looking for Object 421200..	 (114/159250)
# Looking for Object 421342..	 (115/159250)
# Looking for Object 421458..	 (116/159250)
# Looking for Object 421806..	 (117/159250)
# Looking for Object 422801..	 (118/159250)
# Looking for Object 423963..	 (119/159250)
# Looking for Object 421499..	 (120/159250)
# Looking for Object 422221..	 (121/159250)
# Looking for Object 418443..	 (122/159250)
# Looking for Object 418540..	 (123/159250)
# Looking for Object 419209..	 (124/159250)
# Looking for Object 421000..	 (125/159250)
# Looking for Object 424005..	 (126/159250)
# Looking for Object 426294..	 (127/159250)
# Looking for Object 419644..	 (128/159250)
# Looking for Object 419762..	 (129/159250)
# Looking for Object 418524..	 (130/159250)
# Looking for Object 418698..	 (131/159250)
# Looking for Object 418998..	 (132/159250)
# Looking for Object 419305..	 (133/159250)
# Looking for Object 418882..	 (134/159250)
# Looking for Object 419736..	 (135/159250)
# Looking for Object 419721..	 (136/159250)
# Looking for Object 420071..	 (137/159250)
# Looking for Object 419918..	 (138/159250)
# Looking for Object 421616..	 (139/159250)
# Looking for Object 422868..	 (140/159250)
# Looking for Object 420652..	 (141/159250)
# Looking for Object 422134..	 (142/159250)
# Looking for Object 423521..	 (143/159250)
# Looking for Object 423821..	 (144/159250)
# Looking for Object 425598..	 (145/159250)
# Looking for Object 421747..	 (146/159250)
# Looking for Object 423748..	 (147/159250)
# Looking for Object 430909..	 (148/159250)
# Looking for Object 433514..	 (149/159250)
# Looking for Object 427200..	 (150/159250)
# Looking for Object 425844..	 (151/159250)
# Looking for Object 424823..	 (152/159250)
# Looking for Object 425119..	 (153/159250)
# Looking for Object 427905..	 (154/159250)
# Looking for Object 427351..	 (155/159250)
# Looking for Object 429313..	 (156/159250)
# Looking for Object 420037..	 (157/159250)
# Looking for Object 421422..	 (158/159250)
# Looking for Object 421442..	 (159/159250)
# Looking for Object 421123..	 (160/159250)
# Looking for Object 422179..	 (161/159250)
# Looking for Object 422077..	 (162/159250)
# Looking for Object 426809..	 (163/159250)
# Looking for Object 423090..	 (164/159250)
# Looking for Object 423889..	 (165/159250)
# Looking for Object 424862..	 (166/159250)
# Looking for Object 425302..	 (167/159250)
# Looking for Object 424413..	 (168/159250)
# Looking for Object 424996..	 (169/159250)
# Looking for Object 426833..	 (170/159250)
# Looking for Object 434236..	 (171/159250)
# Looking for Object 423635..	 (172/159250)
# Looking for Object 425644..	 (173/159250)
# Looking for Object 426561..	 (174/159250)
# Looking for Object 429101..	 (175/159250)
# Looking for Object 429575..	 (176/159250)
# Looking for Object 427438..	 (177/159250)
# Looking for Object 431065..	 (178/159250)
# Looking for Object 431414..	 (179/159250)
# Looking for Object 425032..	 (180/159250)
# Looking for Object 425177..	 (181/159250)
# Looking for Object 425917..	 (182/159250)
# Looking for Object 425620..	 (183/159250)
# Looking for Object 427063..	 (184/159250)
# Looking for Object 427158..	 (185/159250)
# Looking for Object 428312..	 (186/159250)
# Looking for Object 433410..	 (187/159250)
# Looking for Object 427359..	 (188/159250)
# Looking for Object 428015..	 (189/159250)
# Looking for Object 430612..	 (190/159250)
# Looking for Object 432214..	 (191/159250)
# Looking for Object 432543..	 (192/159250)
# Looking for Object 431929..	 (193/159250)
# Looking for Object 430564..	 (194/159250)
# Looking for Object 430567..	 (195/159250)
# Looking for Object 432809..	 (196/159250)
# Looking for Object 431155..	 (197/159250)
# Looking for Object 432036..	 (198/159250)
# Looking for Object 431883..	 (199/159250)
# Looking for Object 432304..	 (200/159250)
# Looking for Object 417960..	 (201/159250)
# Looking for Object 418134..	 (202/159250)
# Looking for Object 418477..	 (203/159250)
# Looking for Object 418181..	 (204/159250)
# Looking for Object 418993..	 (205/159250)
# Looking for Object 419189..	 (206/159250)
# Looking for Object 420395..	 (207/159250)
# Looking for Object 421450..	 (208/159250)
# Looking for Object 420613..	 (209/159250)
# Looking for Object 422293..	 (210/159250)
# Looking for Object 418000..	 (211/159250)
# Looking for Object 418934..	 (212/159250)
# Looking for Object 418967..	 (213/159250)
# Looking for Object 419603..	 (214/159250)
# Looking for Object 420268..	 (215/159250)
# Looking for Object 421182..	 (216/159250)
# Looking for Object 421966..	 (217/159250)
# Looking for Object 419795..	 (218/159250)
# Looking for Object 419927..	 (219/159250)
# Looking for Object 420446..	 (220/159250)
# Looking for Object 420491..	 (221/159250)
# Looking for Object 421181..	 (222/159250)
# Looking for Object 420158..	 (223/159250)
# Looking for Object 420526..	 (224/159250)
# Looking for Object 423381..	 (225/159250)
# Looking for Object 421683..	 (226/159250)
# Looking for Object 421721..	 (227/159250)
# Looking for Object 422136..	 (228/159250)
# Looking for Object 422942..	 (229/159250)
# Looking for Object 423160..	 (230/159250)
# Looking for Object 425323..	 (231/159250)
# Looking for Object 431483..	 (232/159250)
# Looking for Object 421067..	 (233/159250)
# Looking for Object 421743..	 (234/159250)
# Looking for Object 426491..	 (235/159250)
# Looking for Object 422061..	 (236/159250)
# Looking for Object 423083..	 (237/159250)
# Looking for Object 426080..	 (238/159250)
# Looking for Object 422899..	 (239/159250)
# Looking for Object 423940..	 (240/159250)
# Looking for Object 425060..	 (241/159250)
# Looking for Object 424112..	 (242/159250)
# Looking for Object 425097..	 (243/159250)
# Looking for Object 425840..	 (244/159250)
# Looking for Object 423770..	 (245/159250)
# Looking for Object 425650..	 (246/159250)
# Looking for Object 426030..	 (247/159250)
# Looking for Object 426476..	 (248/159250)
# Looking for Object 424848..	 (249/159250)
# Looking for Object 425456..	 (250/159250)
# Looking for Object 426810..	 (251/159250)
# Looking for Object 424887..	 (252/159250)
# Looking for Object 426694..	 (253/159250)
# Looking for Object 428099..	 (254/159250)
# Looking for Object 430272..	 (255/159250)
# Looking for Object 427750..	 (256/159250)
# Looking for Object 428052..	 (257/159250)
# Looking for Object 429983..	 (258/159250)
# Looking for Object 428122..	 (259/159250)
# Looking for Object 428154..	 (260/159250)
# Looking for Object 428831..	 (261/159250)
# Looking for Object 420352..	 (262/159250)
# Looking for Object 421700..	 (263/159250)
# Looking for Object 421857..	 (264/159250)
# Looking for Object 422680..	 (265/159250)
# Looking for Object 422025..	 (266/159250)
# Looking for Object 422066..	 (267/159250)
# Looking for Object 423292..	 (268/159250)
# Looking for Object 423791..	 (269/159250)
# Looking for Object 423431..	 (270/159250)
# Looking for Object 424458..	 (271/159250)
# Looking for Object 424829..	 (272/159250)
# Looking for Object 423988..	 (273/159250)
# Looking for Object 424460..	 (274/159250)
# Looking for Object 424545..	 (275/159250)
# Looking for Object 426377..	 (276/159250)
# Looking for Object 425485..	 (277/159250)
# Looking for Object 422542..	 (278/159250)
# Looking for Object 422968..	 (279/159250)
# Looking for Object 423073..	 (280/159250)
# Looking for Object 424642..	 (281/159250)
# Looking for Object 425340..	 (282/159250)
# Looking for Object 425543..	 (283/159250)
# Looking for Object 427032..	 (284/159250)
# Looking for Object 429661..	 (285/159250)
# Looking for Object 427225..	 (286/159250)
# Looking for Object 427639..	 (287/159250)
# Looking for Object 427740..	 (288/159250)
# Looking for Object 428844..	 (289/159250)
# Looking for Object 427037..	 (290/159250)
# Looking for Object 426137..	 (291/159250)
# Looking for Object 426808..	 (292/159250)
# Looking for Object 427081..	 (293/159250)
# Looking for Object 427375..	 (294/159250)
# Looking for Object 426210..	 (295/159250)
# Looking for Object 427072..	 (296/159250)
# Looking for Object 427199..	 (297/159250)
# Looking for Object 427464..	 (298/159250)
# Looking for Object 426822..	 (299/159250)
# Looking for Object 428121..	 (300/159250)
# Looking for Object 428901..	 (301/159250)
# Looking for Object 431429..	 (302/159250)
# Looking for Object 429153..	 (303/159250)
# Looking for Object 429366..	 (304/159250)
# Looking for Object 429878..	 (305/159250)
# Looking for Object 430691..	 (306/159250)
# Looking for Object 427174..	 (307/159250)
# Looking for Object 427569..	 (308/159250)
# Looking for Object 429138..	 (309/159250)
# Looking for Object 430367..	 (310/159250)
# Looking for Object 430321..	 (311/159250)
# Looking for Object 428846..	 (312/159250)
# Looking for Object 435874..	 (313/159250)
# Looking for Object 430463..	 (314/159250)
# Looking for Object 430668..	 (315/159250)
# Looking for Object 431766..	 (316/159250)
# Looking for Object 432128..	 (317/159250)
# Looking for Object 431170..	 (318/159250)
# Looking for Object 431194..	 (319/159250)
# Looking for Object 435096..	 (320/159250)
# Looking for Object 432137..	 (321/159250)
# Looking for Object 424519..	 (322/159250)
# Looking for Object 430054..	 (323/159250)
# Looking for Object 434489..	 (324/159250)
# Looking for Object 426999..	 (325/159250)
# Looking for Object 430673..	 (326/159250)
# Looking for Object 431832..	 (327/159250)
# Looking for Object 434894..	 (328/159250)
# Looking for Object 427772..	 (329/159250)
# Looking for Object 430718..	 (330/159250)
# Looking for Object 431187..	 (331/159250)
# Looking for Object 428242..	 (332/159250)
# Looking for Object 429626..	 (333/159250)
# Looking for Object 437693..	 (334/159250)
# Looking for Object 433782..	 (335/159250)
# Looking for Object 432402..	 (336/159250)
# Looking for Object 433031..	 (337/159250)
# Looking for Object 435403..	 (338/159250)
# Looking for Object 441604..	 (339/159250)
# Looking for Object 431459..	 (340/159250)
# Looking for Object 432293..	 (341/159250)
# Looking for Object 432371..	 (342/159250)
# Looking for Object 436019..	 (343/159250)
# Looking for Object 432725..	 (344/159250)
# Looking for Object 432895..	 (345/159250)
# Looking for Object 431710..	 (346/159250)
# Looking for Object 433674..	 (347/159250)
# Looking for Object 433907..	 (348/159250)
# Looking for Object 434372..	 (349/159250)
# Looking for Object 437511..	 (350/159250)
# Looking for Object 434823..	 (351/159250)
# Looking for Object 435482..	 (352/159250)
# Looking for Object 435776..	 (353/159250)
# Looking for Object 436432..	 (354/159250)
# Looking for Object 437857..	 (355/159250)
# Looking for Object 437861..	 (356/159250)
# Looking for Object 435908..	 (357/159250)
# Looking for Object 437019..	 (358/159250)
# Looking for Object 434647..	 (359/159250)
# Looking for Object 434200..	 (360/159250)
# Looking for Object 436689..	 (361/159250)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1270, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1269 try:
# -> 1270     return func(*args, **kwargs)
#    1271 except Exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 14
#      11 if (ramin <= obj['RAJ2000'][i] <= ramax) and (decmin <= obj['DEJ2000'][i] <= decmax):
#      12     #print('in range')
#      13     f = fits.open(path + "/" + file)
# ---> 14     w = WCS(f[1].header,fix=False) # sets up world coordinate system conversions; fix=false fixes it spitting a bunch of wordvomit as it fixes all of the nonstandard stuff in the fits. i dont think it changes the result. if it does. uncomment.
#      15     xpix, ypix = w.all_world2pix(obj['RAJ2000'][i],obj['DEJ2000'][i],1) # convert from RA/DEC to pixel position
#      16     if (0 <= xpix <= f[1].header['NAXIS1'] and 0 <= ypix <= f[1].header['NAXIS2']):
#      17         #print(f'0 <= {xpix} <= {f[1].header['NAXIS1']} and 0 <= {ypix} <= {f[1].header['NAXIS2']}) <TRUE>')
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:390, in HDUList.__getitem__(self, key)
#     386 # Originally this used recursion, but hypothetically an HDU with
#     387 # a very large number of HDUs could blow the stack, so use a loop
#     388 # instead
#     389 try:
# --> 390     return self._try_while_unread_hdus(
#     391         super().__getitem__, self._positive_index_of(key)
#     392     )
#     393 except IndexError as e:
#     394     # Raise a more helpful IndexError if the file was not fully read.
#     395     if self._read_all:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1272, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1270     return func(*args, **kwargs)
#    1271 except Exception:
# -> 1272     if self._read_next_hdu():
#    1273         continue
#    1274     else:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1311, in HDUList._read_next_hdu(self)
#    1308             offset = last._data_offset + last._data_size
#    1309             fileobj.seek(offset, os.SEEK_SET)
# -> 1311     hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1312 except EOFError:
#    1313     self._read_all = True
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/base.py:371, in _BaseHDU.readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     365 hdu = cls._readfrom_internal(
#     366     fileobj, checksum=checksum, ignore_missing_end=ignore_missing_end, **kwargs
#     367 )
#     369 # If the checksum had to be checked the data may have already been read
#     370 # from the file, in which case we don't want to seek relative
# --> 371 fileobj.seek(hdu._data_offset + hdu._data_size, os.SEEK_SET)
#     372 return hdu
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/file.py:453, in _File.seek(self, offset, whence)
#     451 if not hasattr(self._file, "seek"):
#     452     return
# --> 453 self._file.seek(offset, whence)
#     454 pos = self._file.tell()
#     455 if self.size and pos > self.size:
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/gzip.py:421, in GzipFile.seek(self, offset, whence)
#     419 elif self.mode == READ:
#     420     self._check_not_closed()
# --> 421     return self._buffer.seek(offset, whence)
#     423 return self.offset
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/_compression.py:153, in DecompressReader.seek(self, offset, whence)
#     151 # Read and discard data until we reach the desired position.
#     152 while offset > 0:
# --> 153     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     154     if not data:
#     155         break
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/gzip.py:537, in _GzipReader.read(self, size)
#     535     uncompress = self._decompressor.decompress(buf, size)
#     536 else:
# --> 537     uncompress = self._decompressor.decompress(b"", size)
#     539 if self._decompressor.unused_data != b"":
#     540     # Prepend the already read bytes to the fileobj so they can
#     541     # be seen by _read_eof() and _read_gzip_header()
#     542     self._fp.prepend(self._decompressor.unused_data)
#
# KeyboardInterrupt:

# %% [markdown]
# Preloading lets us keep the files in memory, so we don't have to read it in, but it takes some RAM. Crashes if we read in the weight files.

# %%
path = r"/home/#######/Research/Deconvolution/fits"
# Preload FITS headers and data
def preload_fits_files(pa):
    fits_data = {}
    for file in listdir(pa):
        if file.endswith('.fits'):  # Ensure it's a FITS file
            f = fits.open(path + "/" + file)
            header = f[1].header # Get WCS header for pixel to RA/Dec conversion
            weight = f[4].data  # Load only the necessary data extension
            fits_data[file] = {'wcs': header, 'weight': weight}
            f.close()  # Close the file after loading the necessary information
    return fits_data

# %% [markdown]
# We are making masks now

# %% [markdown]
# If we make a binary mask of where we have data, we can use it with less space.

# %%
from os import listdir
from astropy.io import fits
import numpy as np
path = r"/home/eliasw/OneDrive/Research/Deconvolution/fits"

import warnings
warnings.filterwarnings("ignore")

for file in listdir(path): # look through each file
    # Load the weight array
    weight = fits.getdata(path + "/" + file, ext=4)
    # Initialize immask as an array of zeros with the same shape as weight
    immask = np.zeros_like(weight, dtype=int)
    # Set immask to 1 where weight is greater than 0
    immask[weight > 0] = 1
    # Convert immask to an 8-bit integer
    immask_8bit = immask.astype(np.uint8)
    # Open the original FITS file to copy the header from the weight extension
    header = fits.getheader(path + "/" + file, ext=4)  # Assuming ext=4 for weight
    header['EXTNAME'] = "MASK"
    # Create a new FITS PrimaryHDU with immask data and header
    hdu = fits.PrimaryHDU(data=immask_8bit, header=header)
    # Save the new FITS file with the mask data
    output_path = path + "/mask/" + file
    output_path = output_path.replace('.fits.gz','_mask.fits')
    hdu.writeto(output_path, overwrite=True)
    print(f"Mask FITS file saved at {output_path}")
# Out:
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A4_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A5_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A10_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A1_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A3_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A2_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A8_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A7_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A6_v0_5_i2d_mask.fits
# Mask FITS file saved at /home/eliasw/OneDrive/Research/Deconvolution/fits/mask/mosaic_miri_f770w_COSMOS-Web_60mas_A9_v0_5_i2d_mask.fits
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[28], line 11
#       7 warnings.filterwarnings("ignore")
#       9 for file in listdir(path): # look through each file
#      10     # Load the weight array
# ---> 11     weight = fits.getdata(path + "/" + file, ext=4)
#      12     # Initialize immask as an array of zeros with the same shape as weight
#      13     immask = np.zeros_like(weight, dtype=int)
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/convenience.py:220, in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     215 extver = kwargs.get("extver")
#     216 ext_given = not (
#     217     len(args) == 0 and ext is None and extname is None and extver is None
#     218 )
# --> 220 hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     221 try:
#     222     hdu = hdulist[extidx]
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/convenience.py:1121, in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
#    1118 elif extver and extname is None:
#    1119     raise TypeError("extver alone cannot specify an extension.")
# -> 1121 hdulist = fitsopen(filename, mode=mode, **kwargs)
#    1123 return hdulist, ext
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:223, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     220 if not name:
#     221     raise ValueError(f"Empty filename: {name!r}")
# --> 223 return HDUList.fromfile(
#     224     name,
#     225     mode,
#     226     memmap,
#     227     save_backup,
#     228     cache,
#     229     lazy_load_hdus,
#     230     ignore_missing_simple,
#     231     use_fsspec=use_fsspec,
#     232     fsspec_kwargs=fsspec_kwargs,
#     233     decompress_in_memory=decompress_in_memory,
#     234     **kwargs,
#     235 )
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:487, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     468 @classmethod
#     469 def fromfile(
#     470     cls,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     Creates an `HDUList` instance from a file-like object.
#     482
#    (...)
#     485     documentation for details of the parameters accepted by this method).
#     486     """
# --> 487     return cls._readfrom(
#     488         fileobj=fileobj,
#     489         mode=mode,
#     490         memmap=memmap,
#     491         save_backup=save_backup,
#     492         cache=cache,
#     493         ignore_missing_simple=ignore_missing_simple,
#     494         lazy_load_hdus=lazy_load_hdus,
#     495         **kwargs,
#     496     )
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/miniconda3/envs/deconvolution/lib/python3.12/site-packages/astropy/io/fits/file.py:643, in _File._open_filename(self, filename, mode, overwrite)
#     640     self._overwrite_existing(overwrite, None, True)
#     642 if os.path.exists(self.name):
# --> 643     with open(self.name, "rb") as f:
#     644         magic = f.read(4)
#     645 else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/home/eliasw/OneDrive/Research/Deconvolution/fits/mask'

# %%
def preload_fits_files(path):
    fits_data = {}
    for file in listdir(path):
        if file.endswith('.fits.gz'):  # Ensure it's a FITS file
            header = WCS(fits.getheader(path + '/' + file, ext=1), fix=False)  # Get WCS header for pixel to RA/Dec conversion
            mask = fits.getdata((path + '/mask/' + file).replace('.fits.gz','_mask.fits'))  # Load only the necessary data extension
            fits_data[file] = {'wcs': header, 'mask': mask}
    return fits_data

# %% [markdown]
# THIS WORKS SO MUCH BETTER.\
# DID ALL 160k in 5 minutes.

# %% [markdown]
# ### Final Version (also in the form of a .py function)

# %%
# import dependancies
import pandas as pd
import numpy as np
from astropy.io import fits
from astropy.wcs import WCS
from os import listdir
import multiprocessing as mp

# focus out warnings about fits handling that bloat the console
import warnings
warnings.filterwarnings("ignore")

# Define the path to the FITS files
path = r"/home/#/Research/Deconvolution/fits"

# Load the galaxy data and FITS file ranges
obj = pd.read_csv('withinrangeCOSMOS2020.csv', sep=',', header=0)
ranges = pd.read_csv('fitsrange.txt', sep='\t', header=0)

# Preload FITS headers and data
def preload_fits_files(path):
    fits_data = {}
    for file in listdir(path):
        if file.endswith('.fits.gz'):  # Ensure it's a FITS file
            header = WCS(fits.getheader(path + '/' + file, ext=1), fix=False)  # Get WCS header for pixel to RA/Dec conversion
            mask = fits.getdata((path + '/mask/' + file).replace('.fits.gz','_mask.fits'))  # Load only the necessary data extension
            fits_data[file] = {'wcs': header, 'mask': mask}
    return fits_data

# Function to search for galaxies in preloaded FITS files for a subset of galaxies
def search_galaxies(start_index, end_index, fits_data):
    foundgals = 0
    found_objects = []
    end_index = min(end_index, len(obj)) #indexing fix
    #print(f"Processing indices from {start_index} to {end_index}")

    for i in range(start_index, end_index):
       # print(f"Checking index {i}, Galaxy ID {obj['Classic'][i]}") 
        for file, file_data in fits_data.items():  # Loop through preloaded FITS data
            ramin = float(ranges[ranges['File'] == file]['RAmin'])
            ramax = float(ranges[ranges['File'] == file]['RAmax'])
            decmin = float(ranges[ranges['File'] == file]['DECmin'])
            decmax = float(ranges[ranges['File'] == file]['DECmax'])
            # Check if the galaxy is within the RA/Dec range of the file
            if ramin <= obj['RAJ2000'][i]:
                if obj['RAJ2000'][i] <= ramax:
                    if decmin <= obj['DEJ2000'][i]:
                        if obj['DEJ2000'][i] <= decmax:
                            w = file_data['wcs']  # Get the preloaded WCS header
                            xpix, ypix = w.all_world2pix(obj['RAJ2000'][i], obj['DEJ2000'][i], 1)
                            # Check if the pixel coordinates are within bounds
                            if (0 <= xpix <= 9600 and 0 <= ypix <= 12455):
                                if (file_data['mask'][int(ypix),int(xpix)] == True):  # Galaxy found
                                    foundgals += 1
                                    #print(f"Galaxy found at index {i}, ID {obj['Classic'][i]} in file {file}, at coords {obj['RAJ2000'][i]} RA and {obj['DEJ2000'][i]} DEC")
                                    found_objects.append([obj['Classic'][i], obj['RAJ2000'][i], obj['DEJ2000'][i], file])  # Save RA, Dec, and file
                                    break  # Stop searching this file if galaxy found
    
    return foundgals, found_objects

# Multi-core processing: split the galaxy list into chunks
if __name__ == '__main__':
    num_cores = mp.cpu_count()  # Use all available cores
    chunk_size = len(obj) // num_cores  # Determine the size of each chunk

    # Preload all FITS files and headers before starting the search
    fits_data = preload_fits_files(path)

    # Create a pool of workers and distribute the work
    with mp.Pool(num_cores) as pool:
        results = [pool.apply_async(search_galaxies, args=(i, i + chunk_size, fits_data)) for i in range(0, len(obj), chunk_size)]
        
        found_gals = 0
        found_objects = []

        for result in results:
            chunk_found_gals, chunk_found_details = result.get()  # Get both elements from the result tuple
            found_gals += chunk_found_gals  # Sum the galaxy count
            found_objects.extend(chunk_found_details)  # Add the found details to the main list

        # Write the results to a file
        with open('found_galaxies.txt', 'w') as out:
            out.write(f'Found {found_gals} galaxies out of {len(obj)}\n')
            out.write('ID\tRAJ2000\tDEJ2000\tFile\n')  # Header for the galaxy details
            for gal in found_objects:
                out.write(f'{gal[0]}\t{gal[1]}\t{gal[2]}\t{gal[3]}\n')  # Write each galaxy's details (RA, Dec, and file)
            out.flush()
